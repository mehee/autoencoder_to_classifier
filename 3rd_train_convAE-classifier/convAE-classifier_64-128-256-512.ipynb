# %%
#!pip install tensorflow_datasets

# %%
#from tensorflow.keras.callbacks import TensorBoard
# try:
#   # %tensorflow_version only exists in Colab.
#   %tensorflow_version 2.x
# except Exception:
#   pass
import tensorflow as tf
from tensorflow.keras.models import load_model
import tensorflow_datasets as tfds
import sys
import h5py
import datetime
#tf.compat.v1.enable_eager_execution()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
sys.path.append('/content/drive/My Drive/convAE_2_classifier')

# %%
from dataset import Dataset
from convAE import convAE

# %%
#tf.keras.backend.clear_session()

# %%
dataset = Dataset('cats_vs_dogs')
IMG_SIZE = 256
input_shape = (IMG_SIZE, IMG_SIZE, 3)
dataset.set_img_size(IMG_SIZE)
train, val, test = dataset.format_data()
# Out:
# Downloading and preparing dataset cats_vs_dogs/4.0.0 (download: 786.68 MiB, generated: Unknown size, total: 786.68 MiB) to /root/tensorflow_datasets/cats_vs_dogs/4.0.0...
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# WARNING:absl:1738 images were corrupted and were skipped
# Shuffling and writing examples to /root/tensorflow_datasets/cats_vs_dogs/4.0.0.incomplete22TKAR/cats_vs_dogs-train.tfrecord
# Dataset cats_vs_dogs downloaded and prepared to /root/tensorflow_datasets/cats_vs_dogs/4.0.0. Subsequent calls will reuse this data.

# %%
BATCH_SIZE = 32
SHUFFLE_BUFFER_SIZE = 1000
train_batches = train.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
validation_batches = val.batch(BATCH_SIZE)
test_batches = test.batch(BATCH_SIZE)

# %%
autoencoder = convAE(input_shape=input_shape)
autoencoder_filters = [64, 128, 256, 512]
autoencoder.create_autoencoder_with_stacked_conv(filters=autoencoder_filters)
weights_dir = "/content/drive/My Drive/convAE_2_classifier/weights/"
filename = "convAE_stacked256_64-128-256-512__20200323-152310_Epoch0040-Loss0.0024_.hdf5"
autoencoder.autoencoder.load_weights(weights_dir + filename)

# %%
mobileNet2 = load_model("/content/drive/My Drive/convAE_2_classifier/weights/classifier/denseNet169_256_weights.h5")
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %%
autoencoder.encoder.trainable = False
autoencoder.decoder.trainable = True
mobileNet2.trainable = False

# %%
# optimizer = tf.keras.optimizers.RMSprop()
# loss=tf.keras.losses.BinaryCrossentropy()
# mobileNet2.compile(optimizer=optimizer, loss=loss)

# %%
autoencoder.encoder.summary()
autoencoder.decoder.summary()
mobileNet2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 64)      1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 256, 256, 64)      36928
# _________________________________________________________________
# batch_normalization (BatchNo (None, 256, 256, 64)      256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 128, 128, 128)     73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 128, 128, 128)     147584
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128, 128, 128)     512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 64, 64, 256)       295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 64, 64, 256)       590080
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64, 64, 256)       1024
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 512)       1180160
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 32, 32, 512)       2359808
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32, 32, 512)       2048
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 512)       0
# =================================================================
# Total params: 4,689,216
# Trainable params: 0
# Non-trainable params: 4,689,216
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# up_sampling2d (UpSampling2D) (None, 32, 32, 512)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 32, 32, 512)       2359808
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 32, 32, 512)       2359808
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 32, 32, 512)       2048
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 64, 64, 512)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 64, 64, 256)       1179904
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 64, 64, 256)       590080
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 64, 64, 256)       1024
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 128, 128, 256)     0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 128, 128, 128)     295040
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 128, 128, 128)     147584
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 128, 128, 128)     512
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 256, 256, 3)       3459
# =================================================================
# Total params: 6,939,267
# Trainable params: 6,937,475
# Non-trainable params: 1,792
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet169 (Model)          (None, 8, 8, 1664)        12642880
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1664)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 1665
# =================================================================
# Total params: 12,644,545
# Trainable params: 0
# Non-trainable params: 12,644,545
# _________________________________________________________________

# %%
combinedModels = tf.keras.Sequential([autoencoder.autoencoder, mobileNet2])

# %%
combinedModels.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Model)                (None, 256, 256, 3)       11628483
# _________________________________________________________________
# sequential (Sequential)      (None, 1)                 12644545
# =================================================================
# Total params: 24,273,028
# Trainable params: 6,937,475
# Non-trainable params: 17,335,553
# _________________________________________________________________

# %%
#combinedModels.load_weights("./drive/My Drive/convAE_2_classifier/weights/combined_models.0199-0.0357.hdf5")

# %%
listToStr = '-'.join(map(str, autoencoder_filters))
model_name = "convAE_stacked-DenseNet"
run_num = '_5_'
file_name = model_name + run_num + str(IMG_SIZE)+ '_' + listToStr + '_'
print(file_name)
# Out:
# convAE_stacked-DenseNet_5_256_64-128-256-512_

# %%
dateTime = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
log_dir="./drive/My Drive/convAE_2_classifier/logs/" + file_name + "_logs_" + dateTime
weights_path="./drive/My Drive/convAE_2_classifier/weights/" + file_name + "_"  + dateTime + "_Epoch{epoch:04d}-Loss{loss:.4f}_.hdf5"
csv_path = "./drive/My Drive/convAE_2_classifier/logs/" + file_name +  "_model_history_" + dateTime + ".csv"

save_weights_callback = tf.keras.callbacks.ModelCheckpoint(filepath=weights_path , monitor='loss', save_weights_only=True, save_freq='epoch', period=10)
tensorboard_callback  = tf.keras.callbacks.TensorBoard(log_dir=log_dir, update_freq='epoch', histogram_freq=0, write_graph=True, write_images=True)
csv_logger = tf.keras.callbacks.CSVLogger(csv_path, separator=',', append=True)
early_stop_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0.001, patience=10, verbose=0, mode='auto', baseline=None, restore_best_weights=False)

callbacks = [save_weights_callback,
             tensorboard_callback,
             csv_logger,
             #early_stop_callback
             ]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
def get_lr_metric(optimizer):
    def lr(y_true, y_pred):
      return optimizer.lr 
    return lr

# %%
base_learning_rate = 0.00001
optimizer = tf.keras.optimizers.RMSprop(lr=base_learning_rate)
#optimizer = tf.keras.optimizers.Adamax(learning_rate=base_learning_rate, beta_1=0.9, beta_2=0.999)
#optimizer = tf.keras.optimizers.Nadam(learning_rate=base_learning_rate, beta_1=0.9, beta_2=0.999)
#optimizer = tf.keras.optimizers.SGD(learning_rate=base_learning_rate, momentum=0.9, nesterov=True)
#optimizer = tf.keras.optimizers.Adadelta(learning_rate=1.0, rho=0.95)
lr_metric = get_lr_metric(optimizer)
combinedModels.compile(optimizer=optimizer,
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy',
                       #lr_metric
                       ])

# %%
loss, acc  = combinedModels.evaluate(validation_batches, steps = 4)
# Out:
# 4/4 [==============================] - 1s 159ms/step - loss: 0.2959 - accuracy: 0.9375

# %%
print(file_name)
# Out:
# convAE_stacked-DenseNet_5_256_64-128-256-512_

# %%
history = combinedModels.fit(train_batches,
                             epochs=50,
                             #initial_epoch=history.epoch[-1],
                             validation_data=validation_batches,
                             validation_steps=4,
                             shuffle=True,
                             callbacks=callbacks)
# Out:
# Epoch 1/50
# 582/582 [==============================] - 345s 593ms/step - loss: 0.2817 - accuracy: 0.9615 - val_loss: 0.3432 - val_accuracy: 0.9531
# Epoch 2/50
# 582/582 [==============================] - 342s 588ms/step - loss: 0.1519 - accuracy: 0.9735 - val_loss: 0.3786 - val_accuracy: 0.9453
# Epoch 3/50
# 582/582 [==============================] - 342s 588ms/step - loss: 0.0973 - accuracy: 0.9797 - val_loss: 0.3502 - val_accuracy: 0.9531
# Epoch 4/50
# 582/582 [==============================] - 345s 592ms/step - loss: 0.0676 - accuracy: 0.9844 - val_loss: 0.2112 - val_accuracy: 0.9531
# Epoch 5/50
# 582/582 [==============================] - 345s 592ms/step - loss: 0.0474 - accuracy: 0.9874 - val_loss: 0.2590 - val_accuracy: 0.9609
# Epoch 6/50
# 582/582 [==============================] - 343s 589ms/step - loss: 0.0343 - accuracy: 0.9895 - val_loss: 0.1792 - val_accuracy: 0.9609
# Epoch 7/50
# 582/582 [==============================] - 342s 588ms/step - loss: 0.0270 - accuracy: 0.9929 - val_loss: 0.1553 - val_accuracy: 0.9688
# Epoch 8/50
# 582/582 [==============================] - 342s 588ms/step - loss: 0.0208 - accuracy: 0.9937 - val_loss: 0.1591 - val_accuracy: 0.9766
# Epoch 9/50
# 582/582 [==============================] - 344s 592ms/step - loss: 0.0182 - accuracy: 0.9948 - val_loss: 0.1805 - val_accuracy: 0.9688
# Epoch 10/50
# 582/582 [==============================] - 342s 588ms/step - loss: 0.0088 - accuracy: 0.9969 - val_loss: 0.1609 - val_accuracy: 0.9609
# Epoch 11/50
# 582/582 [==============================] - 341s 586ms/step - loss: 0.0094 - accuracy: 0.9966 - val_loss: 0.1519 - val_accuracy: 0.9609
# Epoch 12/50
# 582/582 [==============================] - 341s 587ms/step - loss: 0.0107 - accuracy: 0.9969 - val_loss: 0.2250 - val_accuracy: 0.9531
# Epoch 13/50
# 582/582 [==============================] - 344s 591ms/step - loss: 0.0068 - accuracy: 0.9980 - val_loss: 0.1219 - val_accuracy: 0.9766
# Epoch 14/50
# 582/582 [==============================] - 344s 591ms/step - loss: 0.0068 - accuracy: 0.9981 - val_loss: 0.1703 - val_accuracy: 0.9688
# Epoch 15/50
# 582/582 [==============================] - 344s 591ms/step - loss: 0.0065 - accuracy: 0.9976 - val_loss: 0.1994 - val_accuracy: 0.9688
# Epoch 16/50
# 582/582 [==============================] - 342s 587ms/step - loss: 0.0064 - accuracy: 0.9983 - val_loss: 0.2831 - val_accuracy: 0.9531
# Epoch 17/50
# 582/582 [==============================] - 343s 589ms/step - loss: 0.0052 - accuracy: 0.9983 - val_loss: 0.2500 - val_accuracy: 0.9609
# Epoch 18/50
# 582/582 [==============================] - 344s 591ms/step - loss: 0.0029 - accuracy: 0.9990 - val_loss: 0.2117 - val_accuracy: 0.9609
# Epoch 19/50
# 582/582 [==============================] - 344s 590ms/step - loss: 0.0032 - accuracy: 0.9989 - val_loss: 0.3877 - val_accuracy: 0.9531
# Epoch 20/50
# 582/582 [==============================] - 345s 593ms/step - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.3994 - val_accuracy: 0.9531
# Epoch 21/50
# 582/582 [==============================] - 344s 590ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.3297 - val_accuracy: 0.9531
# Epoch 22/50
# 582/582 [==============================] - 342s 587ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 0.2753 - val_accuracy: 0.9531
# Epoch 23/50
# 582/582 [==============================] - 341s 587ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.1533 - val_accuracy: 0.9688
# Epoch 24/50
# 582/582 [==============================] - 341s 586ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.2517 - val_accuracy: 0.9531
# Epoch 25/50
# 582/582 [==============================] - 342s 587ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.2593 - val_accuracy: 0.9531
# Epoch 26/50
# 582/582 [==============================] - 344s 592ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.1760 - val_accuracy: 0.9609
# Epoch 27/50
# 582/582 [==============================] - 344s 591ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.2535 - val_accuracy: 0.9531
# Epoch 28/50
# 582/582 [==============================] - 342s 587ms/step - loss: 0.0017 - accuracy: 0.9998 - val_loss: 0.2449 - val_accuracy: 0.9609
# Epoch 29/50
# 582/582 [==============================] - 342s 587ms/step - loss: 4.8469e-04 - accuracy: 0.9999 - val_loss: 0.2580 - val_accuracy: 0.9531
# Epoch 30/50
# 582/582 [==============================] - 343s 589ms/step - loss: 4.3149e-04 - accuracy: 0.9999 - val_loss: 0.2514 - val_accuracy: 0.9766
# Epoch 31/50
# 582/582 [==============================] - 342s 587ms/step - loss: 4.4357e-04 - accuracy: 0.9999 - val_loss: 0.2207 - val_accuracy: 0.9688
# Epoch 32/50
# 582/582 [==============================] - 344s 592ms/step - loss: 8.5269e-04 - accuracy: 0.9997 - val_loss: 0.2677 - val_accuracy: 0.9609
# Epoch 33/50
# 582/582 [==============================] - 344s 592ms/step - loss: 5.9126e-04 - accuracy: 0.9997 - val_loss: 0.1396 - val_accuracy: 0.9688
# Epoch 34/50
# 582/582 [==============================] - 345s 592ms/step - loss: 3.2924e-04 - accuracy: 0.9998 - val_loss: 0.1820 - val_accuracy: 0.9609
# Epoch 35/50
# 582/582 [==============================] - 345s 592ms/step - loss: 4.7754e-04 - accuracy: 0.9997 - val_loss: 0.1754 - val_accuracy: 0.9531
# Epoch 36/50
# 582/582 [==============================] - 342s 588ms/step - loss: 2.8909e-04 - accuracy: 0.9999 - val_loss: 0.2300 - val_accuracy: 0.9609
# Epoch 37/50
# 582/582 [==============================] - 345s 593ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.2436 - val_accuracy: 0.9609
# Epoch 38/50
# 582/582 [==============================] - 342s 588ms/step - loss: 6.9676e-04 - accuracy: 0.9998 - val_loss: 0.1950 - val_accuracy: 0.9609
# Epoch 39/50
# 582/582 [==============================] - 342s 588ms/step - loss: 1.8541e-04 - accuracy: 1.0000 - val_loss: 0.1580 - val_accuracy: 0.9609
# Epoch 40/50
# 582/582 [==============================] - 343s 589ms/step - loss: 1.8522e-04 - accuracy: 0.9999 - val_loss: 0.2477 - val_accuracy: 0.9688
# Epoch 41/50
# 582/582 [==============================] - 342s 587ms/step - loss: 4.3389e-04 - accuracy: 0.9998 - val_loss: 0.1679 - val_accuracy: 0.9688
# Epoch 42/50
# 582/582 [==============================] - 342s 587ms/step - loss: 5.4232e-04 - accuracy: 0.9997 - val_loss: 0.1959 - val_accuracy: 0.9531
# Epoch 43/50
# 582/582 [==============================] - 344s 592ms/step - loss: 1.0845e-04 - accuracy: 0.9999 - val_loss: 0.2628 - val_accuracy: 0.9531
# Epoch 44/50
# 582/582 [==============================] - 343s 590ms/step - loss: 2.3282e-04 - accuracy: 0.9999 - val_loss: 0.2445 - val_accuracy: 0.9609
# Epoch 45/50
# 582/582 [==============================] - 342s 588ms/step - loss: 4.5488e-04 - accuracy: 0.9999 - val_loss: 0.1560 - val_accuracy: 0.9688
# Epoch 46/50
# 582/582 [==============================] - 344s 592ms/step - loss: 3.6417e-04 - accuracy: 0.9999 - val_loss: 0.2606 - val_accuracy: 0.9609
# Epoch 47/50
# 582/582 [==============================] - 342s 588ms/step - loss: 6.9721e-05 - accuracy: 1.0000 - val_loss: 0.2443 - val_accuracy: 0.9609
# Epoch 48/50
# 582/582 [==============================] - 345s 592ms/step - loss: 1.5507e-04 - accuracy: 0.9999 - val_loss: 0.3153 - val_accuracy: 0.9609
# Epoch 49/50
# 582/582 [==============================] - 344s 592ms/step - loss: 2.3766e-04 - accuracy: 0.9999 - val_loss: 0.2911 - val_accuracy: 0.9375
# Epoch 50/50
# 582/582 [==============================] - 345s 594ms/step - loss: 3.5519e-04 - accuracy: 0.9998 - val_loss: 0.2359 - val_accuracy: 0.9609

# %%
# import os
# import shutil
# os.remove(log_dir)
# shutil.rmtree(log_dir)
