# %%
#!pip install tensorflow_datasets

# %%
#from tensorflow.keras.callbacks import TensorBoard
# try:
#   # %tensorflow_version only exists in Colab.
#   %tensorflow_version 2.x
# except Exception:
#   pass
import tensorflow as tf
from tensorflow.keras.models import load_model
import tensorflow_datasets as tfds
import sys
import h5py
import datetime
#tf.compat.v1.enable_eager_execution()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
sys.path.append('/content/drive/My Drive/convAE_2_classifier')

# %%
from dataset import Dataset
from convAE import convAE

# %%
#tf.keras.backend.clear_session()

# %%
dataset = Dataset('cats_vs_dogs')
IMG_SIZE = 256
input_shape = (IMG_SIZE, IMG_SIZE, 3)
dataset.set_img_size(IMG_SIZE)
train, val, test = dataset.format_data()
# Out:
# Downloading and preparing dataset cats_vs_dogs/4.0.0 (download: 786.68 MiB, generated: Unknown size, total: 786.68 MiB) to /root/tensorflow_datasets/cats_vs_dogs/4.0.0...
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# WARNING:absl:1738 images were corrupted and were skipped
# Shuffling and writing examples to /root/tensorflow_datasets/cats_vs_dogs/4.0.0.incompleteR5WOGM/cats_vs_dogs-train.tfrecord
# Dataset cats_vs_dogs downloaded and prepared to /root/tensorflow_datasets/cats_vs_dogs/4.0.0. Subsequent calls will reuse this data.

# %%
BATCH_SIZE = 32
SHUFFLE_BUFFER_SIZE = 1000
train_batches = train.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
validation_batches = val.batch(BATCH_SIZE)
test_batches = test.batch(BATCH_SIZE)

# %%
autoencoder = convAE(input_shape=input_shape)
autoencoder_filters = [32, 64, 128, 256]
autoencoder.create_autoencoder_with_stacked_conv(filters=autoencoder_filters)
weights_dir = "/content/drive/My Drive/convAE_2_classifier/weights/"
filename = "convAE_stacked256_32-64-128-256__20200323-164116_Epoch0040-Loss0.0045_.hdf5"
autoencoder.autoencoder.load_weights(weights_dir + filename)

# %%
mobileNet2 = load_model("/content/drive/My Drive/convAE_2_classifier/weights/classifier/denseNet169_256_weights.h5")
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %%
autoencoder.encoder.trainable = False
autoencoder.decoder.trainable = True
mobileNet2.trainable = False

# %%
# optimizer = tf.keras.optimizers.RMSprop()
# loss=tf.keras.losses.BinaryCrossentropy()
# mobileNet2.compile(optimizer=optimizer, loss=loss)

# %%
autoencoder.encoder.summary()
autoencoder.decoder.summary()
mobileNet2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 32)      896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 256, 256, 32)      9248
# _________________________________________________________________
# batch_normalization (BatchNo (None, 256, 256, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 128, 128, 64)      18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 128, 128, 64)      36928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128, 128, 64)      256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 64, 64, 128)       73856
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 64, 64, 128)       147584
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64, 64, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 256)       295168
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 32, 32, 256)       590080
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32, 32, 256)       1024
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 256)       0
# =================================================================
# Total params: 1,174,176
# Trainable params: 0
# Non-trainable params: 1,174,176
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# up_sampling2d (UpSampling2D) (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 32, 32, 256)       590080
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 32, 32, 256)       590080
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 32, 32, 256)       1024
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 64, 64, 256)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 64, 64, 128)       295040
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 64, 64, 128)       147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 64, 64, 128)       512
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 128, 128, 128)     0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 128, 128, 64)      73792
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 128, 128, 64)      36928
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 128, 128, 64)      256
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 256, 256, 3)       1731
# =================================================================
# Total params: 1,737,027
# Trainable params: 1,736,131
# Non-trainable params: 896
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet169 (Model)          (None, 8, 8, 1664)        12642880
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1664)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 1665
# =================================================================
# Total params: 12,644,545
# Trainable params: 0
# Non-trainable params: 12,644,545
# _________________________________________________________________

# %%
combinedModels = tf.keras.Sequential([autoencoder.autoencoder, mobileNet2])

# %%
combinedModels.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Model)                (None, 256, 256, 3)       2911203
# _________________________________________________________________
# sequential (Sequential)      (None, 1)                 12644545
# =================================================================
# Total params: 15,555,748
# Trainable params: 1,736,131
# Non-trainable params: 13,819,617
# _________________________________________________________________

# %%
#combinedModels.load_weights("./drive/My Drive/convAE_2_classifier/weights/combined_models.0199-0.0357.hdf5")

# %%
listToStr = '-'.join(map(str, autoencoder_filters))
model_name = "convAE_stacked-DenseNet"
run_num = '_5_'
file_name = model_name + run_num + str(IMG_SIZE)+ '_' + listToStr + '_'
print(file_name)
# Out:
# convAE_stacked-DenseNet_5_256_32-64-128-256_

# %%
dateTime = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
log_dir="./drive/My Drive/convAE_2_classifier/logs/" + file_name + "_logs_" + dateTime
weights_path="./drive/My Drive/convAE_2_classifier/weights/" + file_name + "_"  + dateTime + "_Epoch{epoch:04d}-Loss{loss:.4f}_.hdf5"
csv_path = "./drive/My Drive/convAE_2_classifier/logs/" + file_name +  "_model_history_" + dateTime + ".csv"

save_weights_callback = tf.keras.callbacks.ModelCheckpoint(filepath=weights_path , monitor='loss', save_weights_only=True, save_freq='epoch', period=10)
tensorboard_callback  = tf.keras.callbacks.TensorBoard(log_dir=log_dir, update_freq='epoch', histogram_freq=0, write_graph=True, write_images=True)
csv_logger = tf.keras.callbacks.CSVLogger(csv_path, separator=',', append=True)
early_stop_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0.001, patience=10, verbose=0, mode='auto', baseline=None, restore_best_weights=False)

callbacks = [save_weights_callback,
             tensorboard_callback,
             csv_logger,
             #early_stop_callback
             ]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
print(dateTime)
# Out:
# 20200414-082235

# %%
def get_lr_metric(optimizer):
    def lr(y_true, y_pred):
      return optimizer.lr 
    return lr

# %%
base_learning_rate = 0.00001
optimizer = tf.keras.optimizers.RMSprop(lr=base_learning_rate)
#optimizer = tf.keras.optimizers.Adamax(learning_rate=base_learning_rate, beta_1=0.9, beta_2=0.999)
#optimizer = tf.keras.optimizers.Nadam(learning_rate=base_learning_rate, beta_1=0.9, beta_2=0.999)
#optimizer = tf.keras.optimizers.SGD(learning_rate=base_learning_rate, momentum=0.9, nesterov=True)
#optimizer = tf.keras.optimizers.Adadelta(learning_rate=1.0, rho=0.95)
lr_metric = get_lr_metric(optimizer)
combinedModels.compile(optimizer=optimizer,
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy',
                       #lr_metric
                       ])

# %%
loss, acc  = combinedModels.evaluate(validation_batches, steps = 4)
# Out:
# 4/4 [==============================] - 0s 111ms/step - loss: 1.3059 - accuracy: 0.8438

# %%
print(file_name)
# Out:
# convAE_stacked-DenseNet_5_256_32-64-128-256_

# %%
history = combinedModels.fit(train_batches,
                             epochs=50,
                             #initial_epoch=history.epoch[-1],
                             validation_data=validation_batches,
                             validation_steps=4,
                             shuffle=True,
                             callbacks=callbacks)
# Out:
# Epoch 1/50
# 582/582 [==============================] - 253s 434ms/step - loss: 0.7105 - accuracy: 0.8918 - val_loss: 0.6755 - val_accuracy: 0.8906
# Epoch 2/50
# 582/582 [==============================] - 250s 430ms/step - loss: 0.4732 - accuracy: 0.9108 - val_loss: 0.6935 - val_accuracy: 0.8750
# Epoch 3/50
# 582/582 [==============================] - 250s 429ms/step - loss: 0.3381 - accuracy: 0.9255 - val_loss: 0.5696 - val_accuracy: 0.8750
# Epoch 4/50
# 582/582 [==============================] - 250s 429ms/step - loss: 0.2461 - accuracy: 0.9408 - val_loss: 0.6102 - val_accuracy: 0.8828
# Epoch 5/50
# 582/582 [==============================] - 251s 432ms/step - loss: 0.1860 - accuracy: 0.9501 - val_loss: 0.6231 - val_accuracy: 0.8750
# Epoch 6/50
# 582/582 [==============================] - 251s 432ms/step - loss: 0.1428 - accuracy: 0.9589 - val_loss: 0.5471 - val_accuracy: 0.8906
# Epoch 7/50
# 582/582 [==============================] - 249s 428ms/step - loss: 0.1036 - accuracy: 0.9677 - val_loss: 0.4717 - val_accuracy: 0.8750
# Epoch 8/50
# 582/582 [==============================] - 251s 432ms/step - loss: 0.0781 - accuracy: 0.9737 - val_loss: 0.5967 - val_accuracy: 0.8750
# Epoch 9/50
# 582/582 [==============================] - 251s 432ms/step - loss: 0.0626 - accuracy: 0.9778 - val_loss: 0.4697 - val_accuracy: 0.8984
# Epoch 10/50
# 582/582 [==============================] - 252s 434ms/step - loss: 0.0446 - accuracy: 0.9837 - val_loss: 0.5330 - val_accuracy: 0.8984
# Epoch 11/50
# 582/582 [==============================] - 251s 432ms/step - loss: 0.0353 - accuracy: 0.9875 - val_loss: 0.4819 - val_accuracy: 0.8750
# Epoch 12/50
# 582/582 [==============================] - 249s 428ms/step - loss: 0.0267 - accuracy: 0.9906 - val_loss: 0.4789 - val_accuracy: 0.8828
# Epoch 13/50
# 582/582 [==============================] - 251s 432ms/step - loss: 0.0217 - accuracy: 0.9926 - val_loss: 0.3917 - val_accuracy: 0.8984
# Epoch 14/50
# 582/582 [==============================] - 249s 428ms/step - loss: 0.0178 - accuracy: 0.9942 - val_loss: 0.4301 - val_accuracy: 0.8984
# Epoch 15/50
# 582/582 [==============================] - 252s 433ms/step - loss: 0.0164 - accuracy: 0.9951 - val_loss: 0.4159 - val_accuracy: 0.8906
# Epoch 16/50
# 582/582 [==============================] - 252s 432ms/step - loss: 0.0142 - accuracy: 0.9954 - val_loss: 0.4089 - val_accuracy: 0.8984
# Epoch 17/50
# 582/582 [==============================] - 252s 432ms/step - loss: 0.0104 - accuracy: 0.9975 - val_loss: 0.3790 - val_accuracy: 0.8984
# Epoch 18/50
# 582/582 [==============================] - 252s 433ms/step - loss: 0.0094 - accuracy: 0.9974 - val_loss: 0.5056 - val_accuracy: 0.8906
# Epoch 19/50
# 582/582 [==============================] - 250s 430ms/step - loss: 0.0069 - accuracy: 0.9985 - val_loss: 0.4382 - val_accuracy: 0.9062
# Epoch 20/50
# 582/582 [==============================] - 252s 433ms/step - loss: 0.0070 - accuracy: 0.9983 - val_loss: 0.4413 - val_accuracy: 0.8906
# Epoch 21/50
# 582/582 [==============================] - 250s 430ms/step - loss: 0.0068 - accuracy: 0.9983 - val_loss: 0.3544 - val_accuracy: 0.9062
# Epoch 22/50
# 582/582 [==============================] - 253s 434ms/step - loss: 0.0049 - accuracy: 0.9989 - val_loss: 0.4203 - val_accuracy: 0.8828
# Epoch 23/50
# 582/582 [==============================] - 252s 433ms/step - loss: 0.0037 - accuracy: 0.9990 - val_loss: 0.3535 - val_accuracy: 0.8906
# Epoch 24/50
# 582/582 [==============================] - 253s 434ms/step - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.4904 - val_accuracy: 0.8906
# Epoch 25/50
# 582/582 [==============================] - 253s 435ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.3893 - val_accuracy: 0.9062
# Epoch 26/50
# 582/582 [==============================] - 250s 429ms/step - loss: 0.0030 - accuracy: 0.9995 - val_loss: 0.4418 - val_accuracy: 0.8984
# Epoch 27/50
# 582/582 [==============================] - 251s 431ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.3926 - val_accuracy: 0.8984
# Epoch 28/50
# 582/582 [==============================] - 252s 433ms/step - loss: 0.0036 - accuracy: 0.9990 - val_loss: 0.4130 - val_accuracy: 0.9062
# Epoch 29/50
# 582/582 [==============================] - 250s 429ms/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.5265 - val_accuracy: 0.9062
# Epoch 30/50
# 582/582 [==============================] - 251s 431ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.4937 - val_accuracy: 0.9141
# Epoch 31/50
# 582/582 [==============================] - 252s 433ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.4956 - val_accuracy: 0.9062
# Epoch 32/50
# 582/582 [==============================] - 250s 429ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.4620 - val_accuracy: 0.8984
# Epoch 33/50
# 582/582 [==============================] - 250s 429ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.4642 - val_accuracy: 0.9141
# Epoch 34/50
# 582/582 [==============================] - 250s 429ms/step - loss: 9.1996e-04 - accuracy: 0.9997 - val_loss: 0.4668 - val_accuracy: 0.9062
# Epoch 35/50
# 582/582 [==============================] - 252s 433ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.4975 - val_accuracy: 0.9141
# Epoch 36/50
# 582/582 [==============================] - 250s 429ms/step - loss: 9.4507e-04 - accuracy: 0.9998 - val_loss: 0.4170 - val_accuracy: 0.9062
# Epoch 37/50
# 582/582 [==============================] - 252s 433ms/step - loss: 8.5634e-04 - accuracy: 0.9998 - val_loss: 0.4279 - val_accuracy: 0.9297
# Epoch 38/50
# 582/582 [==============================] - 250s 429ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.3770 - val_accuracy: 0.9297
# Epoch 39/50
# 582/582 [==============================] - 252s 433ms/step - loss: 6.9519e-04 - accuracy: 0.9999 - val_loss: 0.4956 - val_accuracy: 0.9141
# Epoch 40/50
# 582/582 [==============================] - 253s 435ms/step - loss: 5.7689e-04 - accuracy: 0.9999 - val_loss: 0.4458 - val_accuracy: 0.8906
# Epoch 41/50
# 582/582 [==============================] - 252s 433ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.4518 - val_accuracy: 0.9141
# Epoch 42/50
# 582/582 [==============================] - 253s 434ms/step - loss: 4.1862e-04 - accuracy: 0.9999 - val_loss: 0.5346 - val_accuracy: 0.9062
# Epoch 43/50
# 582/582 [==============================] - 252s 434ms/step - loss: 7.9266e-04 - accuracy: 0.9997 - val_loss: 0.4617 - val_accuracy: 0.9219
# Epoch 44/50
# 582/582 [==============================] - 250s 430ms/step - loss: 3.9019e-04 - accuracy: 0.9999 - val_loss: 0.4113 - val_accuracy: 0.9297
# Epoch 45/50
# 582/582 [==============================] - 250s 429ms/step - loss: 3.2845e-04 - accuracy: 0.9999 - val_loss: 0.4688 - val_accuracy: 0.9141
# Epoch 46/50
# 582/582 [==============================] - 252s 433ms/step - loss: 3.9397e-04 - accuracy: 0.9998 - val_loss: 0.4992 - val_accuracy: 0.8984
# Epoch 47/50
# 582/582 [==============================] - 252s 433ms/step - loss: 3.4358e-04 - accuracy: 0.9999 - val_loss: 0.4955 - val_accuracy: 0.9141
# Epoch 48/50
# 582/582 [==============================] - 250s 429ms/step - loss: 3.6020e-04 - accuracy: 0.9999 - val_loss: 0.4730 - val_accuracy: 0.9141
# Epoch 49/50
# 582/582 [==============================] - 252s 433ms/step - loss: 2.4300e-04 - accuracy: 1.0000 - val_loss: 0.5936 - val_accuracy: 0.9297
# Epoch 50/50
# 582/582 [==============================] - 251s 431ms/step - loss: 2.3682e-04 - accuracy: 0.9999 - val_loss: 0.5471 - val_accuracy: 0.9297

# %%
# import os
# import shutil
# os.remove(log_dir)
# shutil.rmtree(log_dir)
